# %% [markdown]
# #(Easy) High performance text processing in Machine Learning*
#
# #ML meetup
# ##*Joint work with Ian Langmore

# %% [markdown]
# #[Rosetta](https://github.com/columbia-applied-data-science/rosetta)
#
# ##Tools for data science with a focus on text processing.
#
# * Focuses on "medium data", i.e. data too big to fit into memory but too small to necessitate the use of a cluster.
# * Integrates with existing scientific Python stack as well as select outside tools.
#
# ## Tools and utilities
#
# ### `cmd`
# * Unix-like command line utilities.  Filters (read from stdin/write to stdout) for files
#
# ### `parallel`
# * Wrappers for Python multiprocessing that add ease of use
# * Memory-friendly multiprocessing
#
# ### `text`
# * Stream text from disk to formats used in common ML processes
# * Write processed text to sparse formats
# * Helpers for ML tools (e.g. Vowpal Wabbit, Gensim, etc...)
# * Other general utilities
#
# ### `workflow`
# * High-level wrappers that have helped with our workflow and provide additional examples of code use
#
# ### `modeling`
# * General ML modeling utilities

# %% [markdown]
# #Lets begin

# %% [markdown]
# ###for the purpose of this tutorial we will be working with a collection of about 1000 declassified government embassy cables
# ###

# %%
import os
import pandas as pd

# %% [markdown]
# #Text Processors

# %% [markdown]
# ##Streamers
# * Data in many text processing problems comes in the form of
#     * flat files
#     * repeated calls to an DB or API
#     * some 'online' stream
# * A lot of these can be handled streaming the data either from disk, DB, API minimizing CPU use
# * In addition, a lot of streaming is embarassingly parallel so can be easily scaled

# %%
#all you realy need to know is that CABLES is the directory where the data (or cables)
#are stored on your machine
DATA = os.environ['DATA']
CABLES = os.path.join(DATA, 'prod', 'declass', 'cables_short')
RAW = os.path.join(CABLES, 'raw')
PROCESSED = os.path.join(CABLES, 'processed')
SPARSE = os.path.join(CABLES, 'sparse')

sfile_path = os.path.join(SPARSE, 'cables-short.vw')
filtered_sfile_path = os.path.join(PROCESSED, 'cables-short-filtered.vw')
sff_path = os.path.join(PROCESSED, 'sff.pkl')

# %% [markdown]
# ## Streaming: given a collection of objects streaming is the paradigm of processing these objects one at a time in memory, extracting relevant information, writing the information, and discarding the original object
#
# ###Note: after a streaming process is complete, the original collection should no longer be needed for the analysis at hand

# %% [markdown]
# * Lets write a simple file streamer

# %%
#filefilter is a module which helps with basic file/dir functions, such as
#retrieving all paths from a given directory and it's subdir's
from rosetta.text import filefilter

# %%
def simple_file_streamer(base_path):
    paths = filefilter.get_paths(base_path, get_iter=True)
    for p in paths:
        with open(p) as f:
            text = f.read()
            yield(text)

# %% [markdown]
# ###In case you haven't worked much with iterators explicitely, here is a small refresher...
# * For those familiar with generator functions, or iterators, you'll notice that this is exactly what we mean by "streamer," i.e. anything that retrieves files or extracts information from therein and has a .next() method
# * python docs have a short intro about generators (http://docs.python.org/2/tutorial/classes.html#generators)

# %%
def my_iter(N):
    i=0
    while True:
        if i == N:
            raise StopIteration
        else:
            yield i
        i += 1

# %%
mi = my_iter(5)

# %%
mi.next()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-14-ac3a2f2d1b09> in <module>()
# ----> 1 mi.next()
#
# <ipython-input-5-74a12da0cc06> in my_iter(N)
#       3     while True:
#       4         if i == N:
# ----> 5             raise StopIteration
#       6         else:
#       7             yield i
#
# StopIteration:

# %%
#note the raised StopIteration; lets see how a for look handles this

for i in my_iter(5):
    print i
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ###so even if you have not thought about iterators, you have been using them throughout
# ###now back to our streamer

# %%
simple_stream = simple_file_streamer(RAW)

# %%
#lets look at what this object is
type(simple_stream)
# Out:
# generator

# %% [markdown]
# ###Note: this is the first time anything is read into memory

# %%
#lets see what the .next() yields (and splitlines to make it more readable)
simple_stream.next().splitlines()
# Out:
# ['UNCLASSIFIED',
#  '',
#  'PAGE 01        ACCRA  01284  091110Z',
#  'ACTION OCS-06',
#  '',
#  'INFO  OCT-00   ADS-00   AF-10    AMAD-01  CA-01    /018 W',
#  '                    ------------------203337  091121Z /38',
#  'O 081104Z FEB 73',
#  'FM AMEMBASSY ACCRA',
#  'TO AMEMBASSY MONROVIA IMMEDIATE',
#  'INFO SECSTATE WASHDC 4185',
#  'AMEMBASSY ABIDJAN',
#  '',
#  'UNCLAS ACCRA 01284',
#  '',
#  'E.O. 12356: N/A',
#  'TAGS: CASC (AKINS, ESTHER)',
#  'SUBJ: WELFARE/WHEREABOUTS: ESTHER AKINS',
#  '',
#  'REF: MONROVIA 01199 (NOTAL)',
#  '',
#  '1. MS. AKINS LAST REGISTERED WITH THE EMBASSY ON MARCH 23,',
#  '1981.  SHE LATER REPORTED SHE WAS DUE TO LEAVE GHANA ON',
#  'MARCH 2, 1982.',
#  '',
#  '2. ATTEMPTS TO REACH HER BY PHONE THROUGH THE INSTITUTE',
#  'OF LINGUISTICS, HER CONTACT ADDRESS AT THE TIME OF HER',
#  '1981-82 STAY IN GHANA AND OTHER MISSIONARIES HAS PROVED',
#  'UNSUCCESSFUL.  THE SOURCE OF LIGHT MISSION IS NOT, RPT NOT,',
#  'KNOWN TO US.',
#  '',
#  '3. WE WILL MAKE ADDITIONAL EFFORTS TO LOCATE MS. AKINS,',
#  'AND WILL INFORM YOU IF WE HAVE ANY SUCCESS, BUT ADDITIONAL',
#  'CONTACT ADDRESSES FOR HER WOULD BE HELPFUL. WRIGHT',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'UNCLASSIFIED',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'NNN']

# %% [markdown]
# * Now since our end goal is to build a topic model we probably want to have a more fexible streamer, i.e. one that can return file ids, text or tokens (based on some predefined tokenizer)
#     * luckily we have one such streamer written

# %%
from rosetta import TextFileStreamer, TokenizerBasic
text_streamer = TextFileStreamer(text_base_path=CABLES, file_type='*', 
                                           tokenizer=TokenizerBasic())

# %%
stream = text_streamer.info_stream()

# %%
stream.next()
# Out:
# {'atime': 1392907527.0,
#  'cached_path': '/Users/danielkrasner/DATA_master/prod/declass/cables_short/raw/1976YAOUND02835',
#  'doc_id': '1976YAOUND02835',
#  'mtime': 1383854248.0,
#  'size': 629,
#  'text': 'UNCLASSIFIED\n\nPAGE 01        YAOUND 02835  060848Z\n\n12\nACTION AF-08\n\nINFO  OCT-01  ISO-00  /009 W\n                       ---------------------     028803\nR 060750Z AUG 76\nFM AMEMBASSY YAOUNDE\nTO AMEMBASSY LAGOS\nSECSTATE WASHDC 9238\n\nUNCLAS YAOUNDE 2835\n\nLAGOS FOR WACASC FILM OFFICER\n\nDEPT FOR AF/EX\n\nE.O. 11652: N/A\nTAGS: AREC, CM\nSUBJ: WEST AFRICAN FILM CIRCUIT\n\nFOLLOWING FILMS POUCHED TO DOUALA AUG. 3:\n\n                              REC D        SENT     REGISTRATION\nTHE NEW LAND                 JULY 20       AUG 3    NO. 2671037\nBUSTING                      JULY 30       AUG 3    NO. 2671038\nSPIRO\n\n\nUNCLASSIFIED\n\n\n\n\nNNN',
#  'tokens': ['unclassified',
#   'page',
#   'yaound',
#   'action',
#   'af',
#   'info',
#   'oct',
#   'iso',
#   'aug',
#   'fm',
#   'amembassy',
#   'yaounde',
#   'amembassy',
#   'lagos',
#   'secstate',
#   'washdc',
#   'unclas',
#   'yaounde',
#   'lagos',
#   'wacasc',
#   'film',
#   'officer',
#   'dept',
#   'e.o',
#   'tags',
#   'arec',
#   'cm',
#   'subj',
#   'west',
#   'african',
#   'film',
#   'circuit',
#   'following',
#   'films',
#   'pouched',
#   'douala',
#   'aug',
#   'rec',
#   'sent',
#   'registration',
#   'new',
#   'land',
#   'july',
#   'aug',
#   'busting',
#   'july',
#   'aug',
#   'spiro',
#   'unclassified',
#   'nnn']}

# %%
#lets take a quick look at TextFileStreamer
TextFileStreamer?

# %% [markdown]
# * Note: you can pass a tokenizer function to TextFileStreamer(), i.e. any function that takes a string of text and returns a list of strings (the "tokens")
#     * We have written a basic tokenizer function and class to add functionality and because the nltk.word_tokenize() was slow
# * It also has a few other nice options such as shuffle, file_type, etc and a bunch of methods

# %%
text = stream.next()['text']

# %%
print text
# Out:
# CONFIDENTIAL
#
# PAGE 01        YAOUND 04345  121110Z
#
# 12-R
# ACTION AF-08
#
# INFO  OCT-01  ISO-00  ONY-00  /009 W
#                        ---------------------     076832
# P 121015Z NOV 76
# FM AMEMBASSY YAOUNDE
# TO SECSTATE WASHDC PRIORITY 206
#
# C O N F I D E N T I A L YAOUNDE 4345
#
# FOR AF/C AND AF/EX
#
# E.O. 11652: GDS
# TAGS: ACOM, EAIR, MILI, PFOR, CM, US
# SUBJECT: BELLO ON WATTS AND AIRPORT SECURITY
#
# REF: (A) STATE 275884; (B) YAOUNDE 4344; (C) STATE 266432
#
# 1. IN NOV 11 MEETING WTH BOUBA BELLO, PRESIDENCY ASSISTANT
# SECRETARY GENERAL, DCM INQUIRED ABOUT STATUS WATTS REQUEST.
# BELLO SAID EBOUA WAS HANDLING MATTER, BUT HE WOULD ATTEMPT
# OBTAIN PROGRESS REPORT.
#
# 2. ON AIRPORT SECURITY, BELLO GAVE DCM COPY CONFIDENTIAL
# LBTTER OF SAME DATE FROM HIM TO FOREIGN MINISTER REFERRING TO
# OFFER OF AIRPORT SECURITY SURVEY AND TRAINING OF CAMEROONIANS
# IN AIRPORT SECURITY. LETTER INDICATES PRESIDENT AHIDJO'S
# INTEREST IN THIS PROJECT AND INSTRUCTS FOREIGN MINISTER TO
# FOLLOW THROUGH.
#
# 3. BELLO INVITED LUNCH 13TH AND IF HE COMES, OPPORTUNITY
#
# WILL PRESENT ITSELF FOR FOLLOW THROUGH ON WATTS.
# SPIRO
#
#
# CONFIDENTIAL
#
#
#
#
# NNN

# %% [markdown]
# text_streamer.tokenizer.text_to_token_list(text)
# #text_streamer.tokenizer.text_to_counter(text)

# %%
#lets look at a few methods
token_stream = text_streamer.token_stream() # returns a generator function which yields a stream of tokens

# %%
token_stream.next() # this is what our basic tokenizer returns (we are skipping stop words and numerics by default)
# Out:
# ['unclassified',
#  'page',
#  'yaound',
#  'action',
#  'af',
#  'info',
#  'oct',
#  'iso',
#  'aug',
#  'fm',
#  'amembassy',
#  'yaounde',
#  'amembassy',
#  'lagos',
#  'secstate',
#  'washdc',
#  'unclas',
#  'yaounde',
#  'lagos',
#  'wacasc',
#  'film',
#  'officer',
#  'dept',
#  'e.o',
#  'tags',
#  'arec',
#  'cm',
#  'subj',
#  'west',
#  'african',
#  'film',
#  'circuit',
#  'following',
#  'films',
#  'pouched',
#  'douala',
#  'aug',
#  'rec',
#  'sent',
#  'registration',
#  'new',
#  'land',
#  'july',
#  'aug',
#  'busting',
#  'july',
#  'aug',
#  'spiro',
#  'unclassified',
#  'nnn']

# %% [markdown]
# text_streamer.doc_id # returns a list of retrieved doc ids etc

# %%
#if you want to use another tokenizer it's easy
import nltk
nltk.word_tokenize(text)
text_streamer_nltk = TextFileStreamer(text_base_path=RAW, file_type='*', 
                                      tokenizer_func=nltk.word_tokenize)

# %%
stream_nltk = text_streamer_nltk.token_stream()

# %%
stream_nltk.next()
# Out:
# ['CONFIDENTIAL',
#  'PAGE',
#  '01',
#  'ZURICH',
#  '00021',
#  '141459Z',
#  '42',
#  'ACTION',
#  'MC-02',
#  'INFO',
#  'OCT-01',
#  'EUR-12',
#  'ISO-00',
#  'PM-04',
#  'SS-15',
#  'SP-02',
#  'EB-07',
#  'AF-06',
#  '/049',
#  'W',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '-',
#  '093901',
#  'R',
#  '141030Z',
#  'JAN',
#  '76',
#  'FM',
#  'AMCONSUL',
#  'ZURICH',
#  'TO',
#  'SECSTATE',
#  'WASHDC',
#  '2221',
#  'INFO',
#  'AMEMBASSY',
#  'BERN',
#  'AMEMBASSY',
#  'NOUAKCHOTT',
#  'C',
#  'O',
#  'N',
#  'F',
#  'I',
#  'D',
#  'E',
#  'N',
#  'T',
#  'I',
#  'A',
#  'L',
#  'ZURICH',
#  '0021',
#  'STADIS//////////////////////////////////////////',
#  'E.O.',
#  '11652',
#  ':',
#  'GDS',
#  'TAGS',
#  ':',
#  'MASS',
#  ',',
#  'MR',
#  'SUBJECT',
#  ':',
#  'REQUEST',
#  'FOR',
#  'INFORMATION',
#  'ON',
#  'PURCHASE',
#  'OF',
#  'ARMS',
#  'AND',
#  'WEAPONS',
#  'IN',
#  'U.S',
#  '1.',
#  'MR.',
#  'WERNER',
#  'ALTENBACH',
#  ',',
#  'WHO',
#  'IDENTIFIED',
#  'HIMSELF',
#  'AS',
#  'A',
#  'SWISS',
#  'NATIONAL',
#  'AND',
#  'A',
#  'REPRESENTATIVE',
#  'OF',
#  'THE',
#  'ZURICH',
#  'OFFICE',
#  'OF',
#  'SOCIETE',
#  'NATIONALE',
#  'INDUSTRIELLE',
#  'ET',
#  'MINIERE',
#  'DE',
#  'LA',
#  'REPUBLIQUE',
#  'ISLAMIQUE',
#  'DE',
#  'MAURITANI',
#  '(',
#  'SNIM',
#  ')',
#  ',',
#  'CALLED',
#  'AT',
#  'CONGEN',
#  'JANUARY',
#  '13.',
#  'ALTENBACH',
#  'INDICATED',
#  'THAT',
#  'HIS',
#  'OFFICE',
#  'IS',
#  'LOCATED',
#  'AT',
#  '15',
#  'WITIKONERSTRASSE',
#  'AND',
#  'HEADED',
#  'BY',
#  'SIEGFRIED',
#  'WEISSKOPF',
#  ',',
#  'ALSO',
#  'A',
#  'SWISS',
#  'NATIONAL.',
#  '2.',
#  'ALTENBACH',
#  'STATED',
#  'THAT',
#  'THE',
#  'OFFICE',
#  'NORMALLY',
#  'IS',
#  'A',
#  'MINING',
#  'EQUIPMENT',
#  'PURCHASING',
#  'AGENCY',
#  'FOR',
#  'THE',
#  'GOVERNMENT',
#  'CONTROLLED',
#  'SNIM',
#  ',',
#  'BUT',
#  'HAS',
#  'RECENTLY',
#  'BEEN',
#  'INSTRUCTED',
#  'TO',
#  'ARRANGE',
#  'FOR',
#  'CONFIDENTIAL',
#  'PURCHASE',
#  'OF',
#  'SEVERAL',
#  'HUNDRED',
#  'MACHINE',
#  'GUNS',
#  'AND',
#  'MORTARS',
#  'WITH',
#  'APPROPRIATE',
#  'AMMUNITION',
#  'FOR',
#  'THE',
#  'MAURITANIAN',
#  'GOVERNMENT.',
#  'ARMS',
#  'ALLEGEDLY',
#  'REQUIRED',
#  'BECAUSE',
#  'OF',
#  'QUOTE',
#  'DANGEROUS',
#  'SITUATION',
#  'UNQUOTE',
#  'CURRENTLY',
#  'EXISTING',
#  'IN',
#  'MAURITANIA.',
#  'ALTENBACH',
#  'WAS',
#  'VAGUE',
#  'ABOUT',
#  'EXACT',
#  'NUMBERS',
#  ',',
#  'CALIBER',
#  'TYPE',
#  ',',
#  'ETC.',
#  'OF',
#  'WEAPONS',
#  'AND',
#  'AMMUNITION',
#  'REQUIRED',
#  'AND',
#  'STRESSED',
#  'DESIRE',
#  'THAT',
#  'INQUIRY',
#  'BE',
#  'TREATED',
#  'IN',
#  'CONFIDENCE.',
#  '3.',
#  'COMMERCIAL',
#  'OFFICER',
#  'EXPLAINED',
#  'THAT',
#  'THIS',
#  'CONGEN',
#  'IS',
#  'NOT',
#  'NORMALLY',
#  'INVOLVED',
#  'IN',
#  'ARMS',
#  'TRANSACTIONS',
#  'AND',
#  'THAT',
#  'THEREFORE',
#  'WE',
#  'CONFIDENTIAL',
#  'CONFIDENTIAL',
#  'PAGE',
#  '02',
#  'ZURICH',
#  '00021',
#  '141459Z',
#  'WOULD',
#  'HAVE',
#  'TO',
#  'LOOK',
#  'INTO',
#  'HOW',
#  'SUCH',
#  'MATTERS',
#  'ARE',
#  'HANDLED.',
#  'HE',
#  'ADDED',
#  'COMMENT',
#  'THAT',
#  'ALL',
#  'ARMS',
#  'AND',
#  'WEAPONS',
#  'EXPORTED',
#  'FROM',
#  'U.S.',
#  'ARE',
#  'SUBJECT',
#  'TO',
#  'MUNITIONS',
#  'CONTROL',
#  'REGULATIONS.',
#  'ALTENBACH',
#  'INDICATED',
#  'HE',
#  'WILL',
#  'CALL',
#  'AGAIN',
#  'IN',
#  'A',
#  'FEW',
#  'DAYS',
#  'FOR',
#  'ADDITIONAL',
#  'INFORMATION.',
#  '4.',
#  'CONGEN',
#  'HAS',
#  'NO',
#  'ADDITIONAL',
#  'INFORMATION',
#  'ON',
#  'SNIM',
#  ',',
#  'WEISSKOPF',
#  ',',
#  'OR',
#  'ALTEN-',
#  'BACH.',
#  'SNIM',
#  'OFFICE',
#  'IS',
#  'NOT',
#  'LISTED',
#  'IN',
#  'LOCAL',
#  'TELEPHONE',
#  'DIRECTORY',
#  'THOUGH',
#  'THERE',
#  'IS',
#  'A',
#  'LISTING',
#  'FOR',
#  'SIEGFRIED',
#  'WEISSKOPF-PURCHASING',
#  'AGENCY.',
#  '5.',
#  'WOULD',
#  'APPRECIATE',
#  'DEPARTMENT',
#  "'S",
#  'GUIDANCE',
#  'ON',
#  'FURTHER',
#  'RESPONSE',
#  'TO',
#  'ALTENBACH.',
#  'NELSON',
#  'CONFIDENTIAL',
#  'NNN']

# %% [markdown]
# #Vowpal Wabbit for LDA Topic Modeling
# * LDA = Latent Dirichlet Allocation
#     * treats each document as a bag of words
#     * a topic is chosen from a topic distribution $p(k)$ where $k=1, \dots , K$
#     * a word is chosen from the k'th topic distribution $p(w|k)$ and thrown into the bag
#     * distrubutions $p(k)$ depends on $\theta$ ~ $Dir(\alpha)$ and $p(w|k)$ depends on $\beta$ a $k\times V$ matrix of word probabilties
#         * these 'latent' variables are chosen to maximize the probability of producing the observed documents, and in turn depend on user chosen parameters $\alpha$ and $\eta$
#     * the model produces two important probability distributions:
#         * $p(w|k)$, the probability of $w$ bring generated by topic $k$ and
#         * $p(k|d)$, the probabilty of topic $k$ being used to generate a randomly chosen word from document $d$
#     * these topic and word weights can be used to understand the semantic structure of the documents as well as generate document feature
#     * for more details about LDA topic modeling see the wonderful Blei, Ng, and Jordan [paper](http://www.cs.princeton.edu/~blei/papers/BleiNgJordan2003.pdf)
# * Vowpal Wabbit
#     * optimized (very fast) C++ library http://hunch.net/~vw/
#     * can find tutorials at https://github.com/JohnLangford/vowpal_wabbit/wiki/Tutorial and
#     https://github.com/columbia-applied-data-science/rosetta/blob/master/examples/vw_helpers.md

# %%
from rosetta.text import text_processors, filefilter, streamers, vw_helpers

# %%
#create the VW format file 
my_tokenizer = text_processors.TokenizerBasic()
stream = streamers.TextFileStreamer(text_base_path=RAW, tokenizer=my_tokenizer)
stream.to_vw(sfile_path, n_jobs=-1, raise_on_bad_id=False)

# %%
### somewhere here run (stick with 5 passes or so...)
# rm -f *cache
#vw --lda 20 --cache_file doc_tokens.cache --passes 5 -p prediction.dat --readable_model topics.dat --bit_precision 16 --lda_D 975 --lda_rho 0.1 --lda_alpha 1 ../sparse/cables-short.vw

# %%
#load the sparse file 
formatter = text_processors.VWFormatter()
sff = text_processors.SFileFilter(formatter)
sff.load_sfile(sfile_path)

# %%
#remove "gaps" in the sequence of numbers (ids)
sff.compactify()
sff.save(PROCESSED + '/sff_basic.pkl')
# Out:
# Compactification done.  self.bit_precision_required = 14
# collisions = 0, vocab_size = 14476
# All collisions resolved

# %%
sff.to_frame().sort_index(by='doc_fraction', ascending=False).head(10)
# Out:
#           doc_freq  token_score  doc_fraction
# token
# fm             829          845      0.849385
# action         829          907      0.849385
# page           829         1325      0.849385
# oct            829          973      0.849385
# info           829         1432      0.849385
# iso            828          852      0.848361
# secstate       827          854      0.847336
# washdc         824          907      0.844262
# nnn            819          830      0.839139
# tags           782          785      0.801230
#
# [10 rows x 3 columns]

# %% [markdown]
# ## Look at LDA results

# %%
#use the LDAResults class from rosetta to convert back to readable, python friendly formats
lda = vw_helpers.LDAResults(PROCESSED + '/topics.dat', 
                            PROCESSED + '/prediction.dat', PROCESSED + '/sff_basic.pkl')

# %%
#look at some of the words
topic_words = lda.pr_token_g_topic.loc[:,'topic_12'].order(ascending=False).index[:10]
lda.sfile_frame.loc[topic_words]
# Out:
#                doc_freq  token_score  doc_fraction
# token
# organism.             1            1      0.001025
# awacas                1            1      0.001025
# disgrace              1            1      0.001025
# believer              1            1      0.001025
# solicited             2            2      0.002049
# middle                7            9      0.007172
# perisin               1            1      0.001025
# idi                   2            2      0.002049
# ''cameroon            1            2      0.001025
# commemorative         3            4      0.003074
#
# [10 rows x 3 columns]

# %%
#look at the topics themselves
lda.print_topics(10)
# Out:
# ========== Printing top 10 tokens in every topic==========
# ------------------------------
# Topic name: topic_00.  P[topic_00] = 0.0271
#              topic_00  doc_freq
# token
# protection.  0.020413         1
# genoa        0.019496         2
# device       0.001991         3
# glebe        0.001038         1
# uninformed   0.000777         1
# keen         0.000718         3
# forgiving    0.000718         1
# premature    0.000718         6
# columbia     0.000718         3
# assit        0.000718         1
#
# ------------------------------
# Topic name: topic_01.  P[topic_01] = 0.0278
#               topic_01  doc_freq
# token
# tioned        0.063519         1
# belabored     0.001077         1
# saturday's    0.000728         1
# women's       0.000707         3
# nehile        0.000462         1
# lake          0.000457         2
# unserious     0.000386         2
# expects       0.000373        14
# meter         0.000373         1
# manufactured  0.000373         7
#
# ------------------------------
# Topic name: topic_02.  P[topic_02] = 0.0392
#             topic_02  doc_freq
# token
# agreemfqt   0.074200         1
# commences   0.032733         1
# ironed      0.027652         1
# cremation   0.023041         9
# farewell    0.017348        10
# plaza       0.016520         1
# zdovc       0.015943         2
# justify     0.015255         3
# reliable    0.013441         4
# complained  0.013423         2
#
# ------------------------------
# Topic name: topic_03.  P[topic_03] = 0.0261
#             topic_03  doc_freq
# token
# unusual     0.018949         4
# belabored   0.000455         1
# glebe       0.000421         1
# dow         0.000277         5
# predicting  0.000261         1
# eximbank    0.000210         4
# unserious   0.000200         2
# markings    0.000196         1
# opera       0.000191         2
# pri         0.000185         1
#
# ------------------------------
# Topic name: topic_04.  P[topic_04] = 0.0278
#                topic_04  doc_freq
# token
# bamileke       0.023252         1
# 'abstain       0.018596         1
# city.          0.010083         1
# solicit        0.010066         1
# insists        0.006491         1
# belabored      0.000395         1
# nfumu          0.000355         1
# professionnel  0.000355         1
# longchamp      0.000355         1
# achievable     0.000355         2
#
# ------------------------------
# Topic name: topic_05.  P[topic_05] = 0.0264
#               topic_05  doc_freq
# token
# searching     0.028985         2
# belabored     0.000447         1
# glebe         0.000414         1
# cw            0.000414         1
# dow           0.000272         5
# renunciation  0.000271         3
# predicting    0.000261         1
# catching      0.000206         1
# communica     0.000206         1
# emphasized    0.000204        16
#
# ------------------------------
# Topic name: topic_06.  P[topic_06] = 0.0255
#             topic_06  doc_freq
# token
# belabored   0.000470         1
# glebe       0.000441         1
# dow         0.000287         5
# predicting  0.000271         1
# unserious   0.000206         2
# opera       0.000197         2
# pri         0.000190         1
# cross       0.000190         4
# mastering   0.000190         1
# oai         0.000180         1
#
# ------------------------------
# Topic name: topic_07.  P[topic_07] = 0.1819
#            topic_07  doc_freq
# token
# noforn     0.080968         2
# preamble   0.061456         2
# father's   0.055679         2
# took       0.037215        25
# tankers    0.025041         1
# capt       0.020269         3
# treatment  0.017772        13
# giamo      0.016974         2
# dislike    0.014577         1
# neslen     0.014133         1
#
# ------------------------------
# Topic name: topic_08.  P[topic_08] = 0.0393
#             topic_08  doc_freq
# token
# bership     0.207765         1
# pronounce   0.028863         1
# organism.   0.025596         1
# derive      0.016587         1
# croatia'    0.013174         1
# loud        0.010361         1
# chasse      0.005601         1
# earliest    0.003005         1
# jews        0.002849         2
# republique  0.002829         2
#
# ------------------------------
# Topic name: topic_09.  P[topic_09] = 0.0256
#              topic_09  doc_freq
# token
# predicting   0.000695         1
# belabored    0.000466         1
# glebe        0.000433         1
# dow          0.000286         5
# focused      0.000239         2
# airplane     0.000230         1
# usinfos      0.000230         1
# weight       0.000206         3
# typewritten  0.000206         1
# unserious    0.000204         2
#
# ------------------------------
# Topic name: topic_10.  P[topic_10] = 0.0425
#                 topic_10  doc_freq
# token
# respectfully    0.021645         1
# tisdelle        0.021625         1
# flanks          0.017589         1
# rules           0.016886         5
# thirds          0.016374         4
# gof             0.015946         1
# ferrari         0.015598         1
# raison          0.011906         1
# infrastracture  0.011713         1
# casting         0.010704         1
#
# ------------------------------
# Topic name: topic_11.  P[topic_11] = 0.0301
#               topic_11  doc_freq
# token
# consultants   0.059625         1
# collection    0.023723         3
# thirty        0.022077         3
# marsectygdbn  0.011955         1
# inc.          0.008423         1
# abeso         0.006332         1
# cw            0.003699         1
# nigerigans    0.002346         1
# belabored     0.000363         1
# unserious     0.000356         2
#
# ------------------------------
# Topic name: topic_12.  P[topic_12] = 0.1436
#                topic_12  doc_freq
# token
# organism.      0.028422         1
# awacas         0.026150         1
# disgrace       0.025394         1
# believer       0.016931         1
# solicited      0.015816         2
# middle         0.015317         7
# perisin        0.014861         1
# idi            0.014578         2
# ''cameroon     0.013256         1
# commemorative  0.013154         3
#
# ------------------------------
# Topic name: topic_13.  P[topic_13] = 0.0260
#             topic_13  doc_freq
# token
# lord        0.010828         4
# custody     0.004762         1
# belabored   0.000463         1
# glebe       0.000435         1
# cross       0.000405         4
# mastering   0.000405         1
# dow         0.000284         5
# predicting  0.000267         1
# unserious   0.000203         2
# opera       0.000195         2
#
# ------------------------------
# Topic name: topic_14.  P[topic_14] = 0.0261
#               topic_14  doc_freq
# token
# grundig       0.018467         1
# belabored     0.000451         1
# glebe         0.000420         1
# function      0.000408        10
# verbally      0.000306         2
# submerged     0.000299         1
# extendable    0.000299         1
# canning       0.000299         1
# dow           0.000273         5
# renunciation  0.000272         3
#
# ------------------------------
# Topic name: topic_15.  P[topic_15] = 0.0452
#               topic_15  doc_freq
# token
# organism.     0.078717         1
# dirgen        0.032361         1
# subsequently  0.019756        10
# dignify       0.014038         2
# vest          0.012276         2
# ruling        0.011657         3
# knew          0.011027         6
# esperer       0.008133         1
# phillip       0.007940         1
# nheile's      0.007673         1
#
# ------------------------------
# Topic name: topic_16.  P[topic_16] = 0.0264
#             topic_16  doc_freq
# token
# lamimo      0.022303         1
# belabored   0.000427         1
# glebe       0.000384         1
# academy     0.000344         2
# money.      0.000344         1
# saturday's  0.000288         1
# tely        0.000277         1
# dow         0.000260         5
# cw          0.000253         1
# predicting  0.000246         1
#
# ------------------------------
# Topic name: topic_17.  P[topic_17] = 0.0330
#              topic_17  doc_freq
# token
# riley        0.050184         2
# drastic      0.043989         1
# longtime     0.036823         1
# gaconese     0.026336         1
# africana     0.009119         1
# socapao      0.006924         1
# matkovich    0.005642         1
# indictments  0.004743         1
# appro        0.001297         2
# glebe        0.000936         1
#
# ------------------------------
# Topic name: topic_18.  P[topic_18] = 0.0372
#              topic_18  doc_freq
# token
# falkenstr    0.132870         1
# ours         0.092382         2
# overly       0.087129         1
# belabored    0.000250         1
# glebe        0.000195         1
# markings     0.000166         1
# crop         0.000155         2
# concurrence  0.000155         6
# cw           0.000154         1
# dow          0.000152         5
#
# ------------------------------
# Topic name: topic_19.  P[topic_19] = 0.1430
#               topic_19  doc_freq
# token
# peaked        0.031884         1
# arabs         0.027105         3
# critics       0.025209         4
# knowledgable  0.019902         1
# konde         0.016990         1
# championship  0.016631         1
# roosevelt     0.016536         1
# capt          0.014484         3
# prague's      0.012323         1
# altogether    0.011789         1

# %%
##
lda.pr_topic_g_doc.T.loc[[0]].plot(kind='bar', figsize=(20,10),
                                   title = 'First Document Topic Weights')

# %%
r = lambda: random.randint(0,255)
print('#%02X%02X%02X' % (r(),r(),r()))

# %%
#or at the average topic probabilties 
import random
my_colors = ["%06x" % random.randint(0,0xFFFFFF) for i in range(20)]
#my_colors = 'rgbkymc'
lda.pr_topic_g_doc.mean(axis=1).plot(kind='bar', figsize=(15,10), color=my_colors,
                                     title='Average Topic Probabilities')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-8e57876d1350> in <module>()
#       4 #my_colors = 'rgbkymc'
#       5 lda.pr_topic_g_doc.mean(axis=1).plot(kind='bar', figsize=(15,10), color=my_colors,
# ----> 6                                      title='Average Topic Probabilities')
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in plot_series(series, label, kind, use_index, rot, xticks, yticks, xlim, ylim, ax, style, grid, legend, logx, logy, secondary_y, **kwds)
#    1797                      secondary_y=secondary_y, **kwds)
#    1798
# -> 1799     plot_obj.generate()
#    1800     plot_obj.draw()
#    1801
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in generate(self)
#     876         self._compute_plot_data()
#     877         self._setup_subplots()
# --> 878         self._make_plot()
#     879         self._post_plot_logic()
#     880         self._adorn_subplots()
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in _make_plot(self)
#    1532             else:
#    1533                 rect = bar_f(ax, self.ax_pos + i * 0.75 / K, y, 0.75 / K,
# -> 1534                              start=start, label=label, **kwds)
#    1535             rects.append(rect)
#    1536             if self.mark_right:
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in f(ax, x, y, w, start, **kwds)
#    1479         if self.kind == 'bar':
#    1480             def f(ax, x, y, w, start=None, **kwds):
# -> 1481                 return ax.bar(x, y, w, bottom=start,log=self.log, **kwds)
#    1482         elif self.kind == 'barh':
#    1483             def f(ax, x, y, w, start=None, log=self.log, **kwds):
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in bar(self, left, height, width, bottom, **kwargs)
#    4976             color = [None] * nbars
#    4977         else:
# -> 4978             color = list(mcolors.colorConverter.to_rgba_array(color))
#    4979             if len(color) == 0:  # until to_rgba_array is changed
#    4980                 color = [[0, 0, 0, 0]]
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba_array(self, c, alpha)
#     409             result = np.zeros((nc, 4), dtype=np.float)
#     410             for i, cc in enumerate(c):
# --> 411                 result[i] = self.to_rgba(cc, alpha)
#     412             return result
#     413
#
# /Users/danielkrasner/anaconda/lib/python2.7/site-packages/matplotlib/colors.pyc in to_rgba(self, arg, alpha)
#     363         except (TypeError, ValueError) as exc:
#     364             raise ValueError(
# --> 365                 'to_rgba: Invalid rgba arg "%s"\n%s' % (str(arg), exc))
#     366
#     367     def to_rgba_array(self, c, alpha=None):
#
# ValueError: to_rgba: Invalid rgba arg "396cbf"
# to_rgb: Invalid rgb arg "396cbf"
# invalid literal for float(): 396cbf

# %% [markdown]
# #Have fun!
